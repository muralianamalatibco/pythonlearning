# %% [markdown]
# <a href="https://colab.research.google.com/github/muralianamala/pythonlearning/blob/main/MockInterview-Python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('netflix.csv')

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df['director'].isna().sum()
# Out:
# 2634

# %%
df.loc[::2, ::2]
# Out:
#      show_id                             title  \
# 0         s1              Dick Johnson Is Dead
# 2         s3                         Ganglands
# 4         s5                      Kota Factory
# 6         s7  My Little Pony: A New Generation
# 8         s9     The Great British Baking Show
# ...      ...                               ...
# 8798   s8799                          Zed Plus
# 8800   s8801                Zindagi Gulzar Hai
# 8802   s8803                            Zodiac
# 8804   s8805                        Zombieland
# 8806   s8807                            Zubaan
#
#                                                    cast          date_added  \
# 0                                                   NaN  September 25, 2021
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  September 24, 2021
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...  September 24, 2021
# 6     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...  September 24, 2021
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.insert(4, 'temp', 'test')

# %%
df.head()
# Out:
#   show_id     type                  title         director  temp  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  test
# 1      s2  TV Show          Blood & Water              NaN  test
# 2      s3  TV Show              Ganglands  Julien Leclercq  test
# 3      s4  TV Show  Jailbirds New Orleans              NaN  test
# 4      s5  TV Show           Kota Factory              NaN  test
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
d1 = df[['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
       'release_year', 'rating']]

# %%
d2 = df[['duration', 'listed_in', 'description']]

# %%
d2.head()
# Out:
#     duration                                          listed_in  \
# 0     90 min                                      Documentaries
# 1  2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 2   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 3   1 Season                             Docuseries, Reality TV
# 4  2 Seasons  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
pd.concat([d2,d1],axis=1).head()
# Out:
#     duration                                          listed_in  \
# 0     90 min                                      Documentaries
# 1  2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 2   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 3   1 Season                             Docuseries, Reality TV
# 4  2 Seasons  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description show_id     type  \
# 0  As her father nears the end of his life, filmm...      s1    Movie
# 1  After crossing paths at a party, a Cape Town t...      s2  TV Show
# 2  To protect his family from a powerful drug lor...      s3  TV Show
# 3  Feuds, flirtations and toilet talk go down amo...      s4  TV Show
# 4  In a city of coaching centers known to train I...      s5  TV Show
#
#                    title         director  \
# 0   Dick Johnson Is Dead  Kirsten Johnson
# 1          Blood & Water              NaN
# ...

# %%
d1.insert(0, 'duration', df['duration'] )

# %%
d1.insert(1, 'listed_in', df['listed_in'] )

# %%
d1.insert(2, 'description', df['description'] )

# %% [markdown]
# 1-6 as one df
#
# last one as another df
#
# user concat

# %%
d1.head()
# Out:
#     duration                                          listed_in  \
# 0     90 min                                      Documentaries
# 1  2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 2   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 3   1 Season                             Docuseries, Reality TV
# 4  2 Seasons  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description show_id     type  \
# 0  As her father nears the end of his life, filmm...      s1    Movie
# 1  After crossing paths at a party, a Cape Town t...      s2  TV Show
# 2  To protect his family from a powerful drug lor...      s3  TV Show
# 3  Feuds, flirtations and toilet talk go down amo...      s4  TV Show
# 4  In a city of coaching centers known to train I...      s5  TV Show
#
#                    title         director  \
# 0   Dick Johnson Is Dead  Kirsten Johnson
# 1          Blood & Water              NaN
# ...

# %%
d = {'apple': 3,'mango':5, 'berry':6}

# %%
type(d)
# Out:
# dict

# %%
d.update({'orange':2})

# %%
d
# Out:
# {'apple': 3, 'mango': 5, 'berry': 6, 'orange': 2}

# %%
for k,v in d.items():
  print(k)
  print(v)
# Out:
# apple
# 3
# mango
# 5
# berry
# 6
# orange
# 2

# %%
d.update({'grapes':4})

# %%
d['eval'] = 6

# %%
d
# Out:
# {'apple': 3, 'mango': 5, 'berry': 6, 'orange': 2, 'grapes': 4, 'eval': 6}

# %% [markdown]
# Indices of 2 numb
# where 2 num = 17

# %% [markdown]
# 0,1
# 1,9
# 2,2
# 3,5
# 4,6
# 5,7
# 6,8
# 7,3
# 8,4
#
# c= 17-1 = 16
# d[1] =0
# c=8
# d[9] = 1

# %%
l1 = [1,9,2,5,6,7,8,3,4]
t = 17
d ={}

for i,num in enumerate(l1):
  c= t-num
  if c in d:
    print('ind', d[c], i)
  else:
    d[num] = i
d
# Out:
# ind 1 6
# {1: 0, 9: 1, 2: 2, 5: 3, 6: 4, 7: 5, 3: 7, 4: 8}

# %%
t=17
d={}
l = [i if ((t-num) in d) for i,num in enumerate(l1) ]
# Out:
#   File "<ipython-input-67-f106ec9d6d48>", line 3
#     l = [i if ((t-num) in d) for i,num in enumerate(l1) ]
#          ^
# SyntaxError: expected 'else' after 'if' expression

# %%
l = [i if (t - num) in d else d.setdefault(num, i) for i, num in enumerate(l1)]

# %%
l
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
for i,j in enumerate(l1):
  print(i,j)
# Out:
# 0 1
# 1 9
# 2 2
# 3 5
# 4 6
# 5 7
# 6 8
# 7 3
# 8 4
